# %% [markdown]
# Write a function translate() that will translate a text into "rövarspråket" (Swedish for "robber's language"). That is, double every consonant and place an occurrence of "o" in between. For example, translate("this is fun") should return the string "tothohisos isos fofunon".

# %%
def translate(n):
    result=""
    consonant="bcdfghjklmnpqrstvwxyzBCDFGHJKLMNPQRSTVWXYZ"
    for letters in n:
        if letters in consonant:
            result=result+letters+"O"+letters
        else:
            result=result+letters
    return result
translate("this is fun")
# Out:
# 'tOthOhisOs isOs fOfunOn'

# %% [markdown]
# Define a function sum() and a function multiply() that sums and multiplies (respectively) all the numbers in a list of numbers. For example, sum([1, 2, 3, 4]) should return 10, and multiply([1, 2, 3, 4]) should return 24

# %%
def sum(l1):
    result=0
    for i in l1:
        result=result+i
    return result
l1=[1,2,3,4]
sum(l1)
# Out:
# 10

# %% [markdown]
# **Define a function reverse() that computes the reversal of a string. For example, reverse("I am testing") should return the string "gnitset ma I**

# %%
def reverse(st):
    result=st[::-1]
    return result
st="i am testing"
reverse(st)
# Out:
# 'gnitset ma i'

# %% [markdown]
# **Define a function is_palindrome() that recognizes palindromes (i.e. words that look the same written backwards). For example, is_palindrome("radar") should return True.**

# %%
def is_palindrom(st):
    if st==st[::-1]:
        return True
    else:
        return False
st=input("enter the string:")
is_palindrom(st)
# Out:
# enter the string:naman
# True

# %% [markdown]
# **Write a function is_member() that takes a value (i.e. a number, string, etc) x and a list of values a, and returns True if x is a member of a, False otherwise.**

# %%
def is_member(x,a):
    if x in a:
        return True
    else:
        return False
x=input("enter the value of x:")
n=int(input("enter the length of list-a:"))
a=[]
for i in range(n):
    temp=input("enter the value of i:")
    a.append(temp)
is_member(x,a)
# Out:
# enter the value of x:5
# enter the length of list-a:5
# enter the value of i:1
# enter the value of i:2
# enter the value of i:3
# enter the value of i:4
# enter the value of i:5
# True

# %% [markdown]
# **Define a function overlapping() that takes two lists and returns True if they have at least one member in common, False otherwise. You may use your is_member() function, or the in operator, but for the sake of the exercise, you should (also) write it using two nested for-loops.**

# %%
def overlapping(l1,l2):
    for i in l1:
        if (i in l1) and (i in l2):
            temp=True
            break
        else:
            temp=False
    return temp

# %%
overlapping([1,2,3],[3,4,5,6])
# Out:
# True

# %% [markdown]
# # *Define a procedure histogram() that takes a list of integers and prints a histogram to the screen. For example, histogram([4, 9, 7]) should print the following:*(click on next cell to see)

# %% [markdown]
# ****
# *********
# *******

# %%
def histogram( items ):
    for n in items:
        output = ''
        times = n
        while( times > 0 ):
          output += '*'
          times = times - 1
        print(output)

# %%
histogram([4,9,7])
# Out:
# ****
# *********
# *******

# %% [markdown]
# **Write a function char_freq() that takes a string and builds a frequency listing of the characters contained in it. Represent the frequency listing as a Python dictionary. Try it with something like char_freq("abbabcbdbabdbdbabababcbcbab").**

# %%
def char_freq(s):
    s1=set(s)
    d={}
    for i in s1:
        count=0
        for j in range(len(s)):
            if i==s[j]:
             count+=1
        d.update({i:count})
    return d

# %%
char_freq("abbabcbdbabdbdbabababcbcbab")
# Out:
# {'d': 3, 'b': 14, 'c': 3, 'a': 7}

# %% [markdown]
# A certain childrens game involves starting with a word in a particular category. Each participant in turn says a word, but that word must begin with the final letter of the previous word. Once a word has been given, it cannot be repeated. If an opponent cannot give a word in the category, they fall out of the game. For example, with "animals" as the category,
# Child 1: dog
# Child 2: goldfish
# Child 1: hippopotamus
# Child 2: snake
# ...
# Your task in this exercise is as follows: Take the following selection of 70 English Pokemon names (extracted from Wikipedia's list of Pokemon) and generate the/a sequence with the highest possible number of Pokemon names where the subsequent name starts with the final letter of the preceding name. No Pokemon name is to be repeated.
# **audino bagon baltoy banette bidoof braviary bronzor carracosta charmeleon
# cresselia croagunk darmanitan deino emboar emolga exeggcute gabite
# girafarig gulpin haxorus heatmor heatran ivysaur jellicent jumpluff kangaskhan
# kricketune landorus ledyba loudred lumineon lunatone machamp magnezone mamoswine
# nosepass petilil pidgeotto pikachu pinsir poliwrath poochyena porygon2
# porygonz registeel relicanth remoraid rufflet sableye scolipede scrafty seaking
# sealeo silcoon simisear snivy snorlax spoink starly tirtouga trapinch treecko
# tyrogue vigoroth vulpix wailord wartortle whismur wingull yamask**

# %%
str1="audino bagon baltoy banette bidoof braviary bronzor carracosta charmeleon cresselia croagunk darmanitan deino emboar emolga exeggcute gabite girafarig gulpin haxorus heatmor heatran ivysaur jellicent jumpluff kangaskhan kricketune landorus ledyba loudred lumineon lunatone machamp magnezone mamoswine nosepass petilil pidgeotto pikachu pinsir poliwrath poochyena porygon2 porygonz registeel relicanth remoraid rufflet sableye scolipede scrafty seaking sealeo silcoon simisear snivy snorlax spoink starly tirtouga trapinch treecko tyrogue vigoroth vulpix wailord wartortle whismur wingull yamask"
l1=str1.split()
l2=[]
for i in l1:
    if i not in l2:
        l2.append(i)
result=[]
temp=""
n=len(l2)
print(l2)
for i in range(len(l2)):
    temp=l2[i]
    result.append(temp)
    #print(result)
    j=0
    while j < n:
        #print(temp)
        if temp[-1]==l2[j][0] and l2[j] not in result:  
            result.append(l2[j])
            temp=result[-1]
            j=0
        j=j+1
        #print(j,"*************",result,temp)
        print(result)
    print("==============================================================================")
    result=[]
# Out:
# ['audino', 'bagon', 'baltoy', 'banette', 'bidoof', 'braviary', 'bronzor', 'carracosta', 'charmeleon', 'cresselia', 'croagunk', 'darmanitan', 'deino', 'emboar', 'emolga', 'exeggcute', 'gabite', 'girafarig', 'gulpin', 'haxorus', 'heatmor', 'heatran', 'ivysaur', 'jellicent', 'jumpluff', 'kangaskhan', 'kricketune', 'landorus', 'ledyba', 'loudred', 'lumineon', 'lunatone', 'machamp', 'magnezone', 'mamoswine', 'nosepass', 'petilil', 'pidgeotto', 'pikachu', 'pinsir', 'poliwrath', 'poochyena', 'porygon2', 'porygonz', 'registeel', 'relicanth', 'remoraid', 'rufflet', 'sableye', 'scolipede', 'scrafty', 'seaking', 'sealeo', 'silcoon', 'simisear', 'snivy', 'snorlax', 'spoink', 'starly', 'tirtouga', 'trapinch', 'treecko', 'tyrogue', 'vigoroth', 'vulpix', 'wailord', 'wartortle', 'whismur', 'wingull', 'yamask']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ['audino']
# ==============================================================================
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['bagon', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ==============================================================================
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['baltoy', 'yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ==============================================================================
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye']
# ['banette', 'emboar', 'registeel', 'landorus', 'sableye', 'emolga']
# ...
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ['yamask', 'kangaskhan', 'nosepass', 'sableye', 'emboar', 'registeel', 'landorus', 'scolipede', 'emolga']
# ==============================================================================

# %% [markdown]
# **Write a program able to play the "Guess the number"-game, where the number to be guessed is randomly chosen between 1 and 20. (Source: http://inventwithpython.com) This is how it should work when run in a terminal:
#
# Hello! What is your name?
# Torbjörn
# Well, Torbjörn, I am thinking of a number between 1 and 20.
# Take a guess.
# 10
# Your guess is too low.
# Take a guess.
# 15
# Your guess is too low.
# Take a guess.
# 18
# Good job, Torbjörn! You guessed my number in 3 guesses!***

# %%
import random 
winning_number= random.randint(1,100)
guess=int(input("guess the winning number:"))
print(guess)
guess_count=0
game_over=False
while not game_over:
    if guess==winning_number:
        print("you win!! and you guessed count is :",guess_count)
        game_over=True
    else:
        if guess<winning_number:
            print("too low")
            guess_count+=1
            guess=int(input("guess again :"))
        else:
            print("too high")
            guess_count+=1
            guess=int(input("guess again :"))
# Out:
# guess the winning number:10
# 10
# too low
# guess again :50
# too high
# guess again :40
# too high
# guess again :30
# too low
# guess again :35
# too high
# guess again :33
# you win!! and you guessed count is : 5

# %% [markdown]
# ***Write a program that maps a list of words into a list of integers representing the lengths of the correponding words.***

# %%
map_int(['te','tes','test','testing'])
# Out:
# [2, 3, 4, 7]
